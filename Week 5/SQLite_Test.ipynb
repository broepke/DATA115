# %% [markdown]
# # Basic SQL Lite with Python
#
# https://realpython.com/python-sql-libraries/

# %%
import pandas as pd
import numpy as np
import sqlite3
from sqlite3 import Error

# %%
def create_connection(path):
    connection = None
    try:
        connection = sqlite3.connect(path)
        print("Connection to SQLite DB successful")
    except Error as e:
        print(f"The error '{e}' occurred")

    return connection

# %%
connection = create_connection("ggu.db")
# Out:
# Connection to SQLite DB successful

# %%
def execute_read_query(connection, query):
    cursor = connection.cursor()
    result = None
    try:
        cursor.execute(query)
        result = cursor.fetchall()
        return result
    except Error as e:
        print(f"The error '{e}' occurred")

# %%
select_students = "SELECT * FROM STUDENTS"

# %%
students = execute_read_query(connection, select_students)

for student in students:
    print(student)
# Out:
# (1, 'Bart', 'Simpson', 'JoJo', 'bart@my.ggu.edu', 'bart@hotmail.com', '(555) 123-1234', 1, 1)
# (2, 'Lisa', 'Simpson', 'Marie', 'lisa@my.ggu.edu', 'lisa@hotmail.com', '(555) 123-1234', 1, 1)
# (3, 'Meg', 'Griffin', '', 'meg@my.ggu.edu', 'meg@gmail.com', '(999) 999-9999', 1, 1)
# (4, 'Christopher', 'Griffin', 'Cross', 'chris@my.ggu.edu', 'chris@gmail.com', '(999) 999-9999', 1, 2)

# %%
type(students)
# Out:
# list

# %%
df = pd.read_sql_query(select_students, connection)
df
# Out:
#    ID    FirstName LastName MiddleName      EmailStudent     EmailPersonal  \
# 0   1         Bart  Simpson       JoJo   bart@my.ggu.edu  bart@hotmail.com
# 1   2         Lisa  Simpson      Marie   lisa@my.ggu.edu  lisa@hotmail.com
# 2   3          Meg  Griffin               meg@my.ggu.edu     meg@gmail.com
# 3   4  Christopher  Griffin      Cross  chris@my.ggu.edu   chris@gmail.com
#
#      PrimaryPhone  Active  DegreeID
# 0  (555) 123-1234       1         1
# 1  (555) 123-1234       1         1
# 2  (999) 999-9999       1         1
# 3  (999) 999-9999       1         2

# %%
df.columns
# Out:
# Index(['ID', 'FirstName', 'LastName', 'MiddleName', 'EmailStudent',
#        'EmailPersonal', 'PrimaryPhone', 'Active', 'DegreeID'],
#       dtype='object')

# %% [markdown]
# ## Inner Join from Multi-Value Table (4NF)

# %%
join = "SELECT * \
FROM STUDENTS as st \
JOIN STUDENT_COURSES as sc \
ON sc.StudentID = st.ID \
JOIN COURSES as co \
ON sc.CourseID = co.ID"

# %%
df2 = pd.read_sql_query(join, connection)
df2
# Out:
#    ID    FirstName LastName MiddleName      EmailStudent     EmailPersonal  \
# 0   1         Bart  Simpson       JoJo   bart@my.ggu.edu  bart@hotmail.com
# 1   1         Bart  Simpson       JoJo   bart@my.ggu.edu  bart@hotmail.com
# 2   1         Bart  Simpson       JoJo   bart@my.ggu.edu  bart@hotmail.com
# 3   2         Lisa  Simpson      Marie   lisa@my.ggu.edu  lisa@hotmail.com
# 4   2         Lisa  Simpson      Marie   lisa@my.ggu.edu  lisa@hotmail.com
# 5   3          Meg  Griffin               meg@my.ggu.edu     meg@gmail.com
# 6   3          Meg  Griffin               meg@my.ggu.edu     meg@gmail.com
# 7   4  Christopher  Griffin      Cross  chris@my.ggu.edu   chris@gmail.com
# 8   4  Christopher  Griffin      Cross  chris@my.ggu.edu   chris@gmail.com
#
#      PrimaryPhone  Active  DegreeID  StudentID  ...  SemesterID  StatusID  \
# 0  (555) 123-1234       1         1          1  ...           1         3
# 1  (555) 123-1234       1         1          1  ...           2         2
# 2  (555) 123-1234       1         1          1  ...           4         1
# 3  (555) 123-1234       1         1          2  ...           1         3
# 4  (555) 123-1234       1         1          2  ...           2         2
# 5  (999) 999-9999       1         1          3  ...           5         1
# 6  (999) 999-9999       1         1          3  ...           5         1
# 7  (999) 999-9999       1         2          4  ...           2         2
# 8  (999) 999-9999       1         2          4  ...           2         2
#
#    Grade ProfessorID  ID     Code                              Name Units  \
# 0      A           2   1  DATA110                  Machine Learning     3
# 1   None           3   2  DATA115              Relational Databases     3
# 2   None           4   3    HUM50                        Humanities     3
# 3      B           2   1  DATA110                  Machine Learning     3
# 4   None           3   2  DATA115              Relational Databases     3
# 5   None           2   1  DATA110                  Machine Learning     3
# 6   None           3   2  DATA115              Relational Databases     3
# 7   None           1   4  MSBA328  Visualization and Communications     3
# 8   None           3   5  MSBA305             Business Intelligence     3
#
#     Location          Level
# 0     Online  Undergraduate
# 1     Online  Undergraduate
# 2     Online  Undergraduate
# 3     Online  Undergraduate
# 4     Online  Undergraduate
# 5     Online  Undergraduate
# 6     Online  Undergraduate
# 7      Mixed       Graduate
# 8  In Person       Graduate
#
# [9 rows x 21 columns]

# %%
df
